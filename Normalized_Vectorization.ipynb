# %%
#Data Science in TSE Systems/MISP Project
#Code written by: Anshak Mallik

# %%
#Importing libraries
import numpy as np
import pandas as pd
# # import nltk
# import re

# %%
#Getting the dataframe from Attributes.csv
data_folder = "Data"
attributes = pd.read_csv(f"{data_folder}/Normalized_Attributes.csv")  #dataframe
attributes = attributes[attributes['Orgc ID'] != 1203]
# attributes = attributes.drop(labels='Unnamed: 0', axis=1)

# %%
attributes
# Out:
#          Event ID  Orgc ID  Org ID  Attribute ID  \
# 28          70840     1092    1368      10058607
# 29          70840     1092    1368      10058655
# 30          70840     1092    1368      10058746
# 31          70840     1092    1368      10058849
# 32          70840     1092    1368      10058930
# ...           ...      ...     ...           ...
# 1048570     14265        2       2       2985358
# 1048571     14265        2       2       2985359
# 1048572     14265        2       2       2985360
# 1048573     14265        2       2       2985361
# 1048574     14265        2       2       2985362
#
#                                          UUID Attribute Type  \
# 28       4a997b87-6a1b-46ab-919c-45562482cf81            url
# 29       69c39a3a-2380-4590-9e2a-4a08e47121e7            url
# 30       5ae40bb2-8858-4790-b0da-3750c908dd6c            url
# 31       fd024a53-7d6c-4870-b618-b99ded2a2eb5            url
# 32       647aa1dd-0703-47b5-9738-495f28b22f11            url
# ...                                       ...            ...
# 1048570  80c646b8-1b51-4749-890d-914c795ad75c       hostname
# 1048571  9ac88862-e433-4bc2-af13-11a7b88efd90       hostname
# 1048572  62ad02b3-58a5-4173-9548-eca913f04fd3       hostname
# 1048573  892695c4-61be-4ce6-b519-e7f3382cde1c       hostname
# 1048574  4f7a7a3f-28a2-4b8b-b63a-b58b54934215       hostname
#
#         Attribute Category  Distribution   Timestamp  Event Date  \
# 28        Network activity             5  1551235874  27/02/2019
# 29        Network activity             5  1551235874  27/02/2019
# 30        Network activity             5  1551235874  27/02/2019
# 31        Network activity             5  1551235874  27/02/2019
# 32        Network activity             5  1551235874  27/02/2019
# ...                    ...           ...         ...         ...
# 1048570   Network activity             5  1553680268  26/03/2019
# 1048571   Network activity             5  1553680271  26/03/2019
# 1048572   Network activity             5  1553680271  26/03/2019
# 1048573   Network activity             5  1553680271  26/03/2019
# 1048574   Network activity             5  1553680281  26/03/2019
#
#          Event Published  Published  Deleted  \
# 28                     0       True    False
# 29                     0       True    False
# 30                     0       True    False
# 31                     0       True    False
# 32                     0       True    False
# ...                  ...        ...      ...
# 1048570                0      False    False
# 1048571                0      False    False
# 1048572                0      False    False
# 1048573                0      False    False
# 1048574                0      False    False
#
#                                                      Value     Comment
# 28       mscgoehrendeen_enscaninvoice_noticegblflwwh_kw...  emotet url
# 29       mscgoehrendeen_enscaninvoice_noticegblflwwh_kw...  emotet url
# 30                  1354153118wpcontentdownloadijxdml_jllt  emotet url
# 31             89nepeanseacomdocumentqxgmhrbn_kkjlieirglna  emotet url
# 32       kebunrayabaturradeniduscopy_invoicetoobiogm_vd...  emotet url
# ...                                                    ...         ...
# 1048570                    fastcellphonecashmotionmanorcom         NaN
# 1048571                     smithplaceglobalmotionmanorcom         NaN
# 1048572                    fastcellphonecashmotionmanorcom         NaN
# 1048573                     smithplaceglobalmotionmanorcom         NaN
# 1048574                              cornerstonelivingcouk         NaN
#
# [1017427 rows x 15 columns]

# %% [markdown]
# ## Normalization

# %%
from collections import OrderedDict

#Creating list with all event IDs (without repetition)
event_ids = attributes['Event ID']
events = list(OrderedDict.fromkeys(event_ids))

# %% [markdown]
# ## Inheritance

# %%
#Loop to see which events have number of values of tolerance
tol = 5e3
counter = 0
big_events = []
big_indices = []

for k in range(len(events)):
    #Getting relevant rows and their attribute IDs
    event_df = attributes.loc[attributes['Event ID'] == events[k]]
    n = len(event_df)
    attribute_ids = event_df['Attribute ID']
    values = np.array(event_df['Value'])
    if len(values) >= tol: 
        print('The following event has too many values (more than %d)!' % (tol))
        print('Index %d, Event ID %d, Values %d' % (k, events[k], len(values)))
        print('----------')
        counter += 1
        big_events.append(events[k])
        big_indices.append(k)
        
print('Total number of events with values over %d: %d' % (tol, counter))
# Out:
# The following event has too many values (more than 5000)!
# Index 93, Event ID 79819, Values 29641
# ----------
# The following event has too many values (more than 5000)!
# Index 152, Event ID 79837, Values 30752
# ----------
# The following event has too many values (more than 5000)!
# Index 267, Event ID 62222, Values 41630
# ----------
# The following event has too many values (more than 5000)!
# Index 1152, Event ID 86173, Values 7814
# ----------
# The following event has too many values (more than 5000)!
# Index 1235, Event ID 14027, Values 33457
# ----------
# The following event has too many values (more than 5000)!
# Index 1339, Event ID 14168, Values 41542
# ----------
# The following event has too many values (more than 5000)!
# Index 1391, Event ID 14223, Values 40520
# ----------
# The following event has too many values (more than 5000)!
# Index 1552, Event ID 62248, Values 34623
# ----------
# The following event has too many values (more than 5000)!
# Index 1975, Event ID 6271, Values 5832
# ----------
# The following event has too many values (more than 5000)!
# Index 2104, Event ID 14320, Values 6880
# ----------
# The following event has too many values (more than 5000)!
# Index 2164, Event ID 69573, Values 11063
# ----------
# The following event has too many values (more than 5000)!
# Index 2280, Event ID 14741, Values 45529
# ----------
# The following event has too many values (more than 5000)!
# Index 2333, Event ID 86170, Values 5244
# ----------
# The following event has too many values (more than 5000)!
# Index 2386, Event ID 15538, Values 19471
# ----------
# The following event has too many values (more than 5000)!
# Index 2415, Event ID 86281, Values 8903
# ----------
# The following event has too many values (more than 5000)!
# Index 2476, Event ID 14711, Values 48083
# ----------
# The following event has too many values (more than 5000)!
# Index 2794, Event ID 14222, Values 41165
# ----------
# The following event has too many values (more than 5000)!
# Index 2799, Event ID 14449, Values 47654
# ----------
# The following event has too many values (more than 5000)!
# Index 2896, Event ID 26321, Values 38790
# ----------
# The following event has too many values (more than 5000)!
# Index 2950, Event ID 90141, Values 8168
# ----------
# The following event has too many values (more than 5000)!
# Index 3023, Event ID 97697, Values 11264
# ----------
# The following event has too many values (more than 5000)!
# Index 3082, Event ID 44677, Values 53184
# ----------
# The following event has too many values (more than 5000)!
# Index 3154, Event ID 62336, Values 21910
# ----------
# The following event has too many values (more than 5000)!
# Index 3270, Event ID 14388, Values 36887
# ----------
# The following event has too many values (more than 5000)!
# Index 3649, Event ID 42970, Values 58354
# ----------
# The following event has too many values (more than 5000)!
# Index 3774, Event ID 14265, Values 17340
# ----------
# Total number of events with values over 5000: 26

# %%
#Filtering events before getting attribute IDs
filtered_events = [x for x in events if x not in big_events]

# %%
# from timeit import default_timer as timer
# from datetime import timedelta
# from difflib import SequenceMatcher
# # import jellyfish as jl

# #Creating subset matrix for example

# #Begin timer before loop
# start = timer()

# #Getting subset data
# N = 100
# attribute_ids_N = np.array(attributes['Attribute ID'][:N]) #Series
# values_N = value[:N] #After normalization

# #Empty matrix
# I = np.zeros((N, N))
# for i in range(N):
#     for j in range(N):
#         if (i >= j):
#             I[i,j] = round(SequenceMatcher(None, values_N[i], values_N[j]).ratio(), 3)
#             # I[i,j] = round(jl.jaro_similarity(values_N[i], values_N[j]), 3)
            
# #Matrix as dataframe
# df = pd.DataFrame(I, index=attribute_ids_N, columns=attribute_ids_N)
# # df.to_csv(r'Data/Inheritance_subset.csv')

# #End timer after loop    
# end = timer()
# print(timedelta(seconds=end-start))

# %%
from timeit import default_timer as timer
from datetime import timedelta

#Getting list of all event and attribute IDs separately
start = timer()
e, a, index = [], [], []
for k in range(len(filtered_events)):
    
    #Filtering using events
    df = attributes.loc[attributes['Event ID'] == filtered_events[k]]
    #Attribute ID
    attribute_ids = df['Attribute ID']
    
    #Indices of rows
    index_list = list(df.index)
    index += index_list
    #Appending e and a
    for l in range(len(attribute_ids)):
        e.append(filtered_events[k])
        a.append(np.array(attribute_ids)[l])
        
    #Checkpoints
    if k%1000 == 0:
        print('%d iterations done in: ' % (k))
        print(timedelta(seconds=timer()-start))
        print('----------')
print(timedelta(seconds=timer()-start))
# Out:
# 0 iterations done in:
# 0:00:00.003686
# ----------
# 1000 iterations done in:
# 0:00:01.456339
# ----------
# 2000 iterations done in:
# 0:00:02.811150
# ----------
# 3000 iterations done in:
# 0:00:04.178825
# ----------
# 0:00:05.228434

# %%
from difflib import SequenceMatcher
#Creating matrix

#Getting the data
N = len(index)
labels = [(ev, at) for ev, at in zip(e, a)]
value = attributes['Value']
values = value[index]

# %%
#Begin timer before loop
start = timer()

#Empty matrix
I = np.zeros((N, N))    
for i in range(N):
    for j in range(N):
        if (i >= j):
            I[i,j] = round(SequenceMatcher(None, values[i], values[j]).ratio(), 3)
    #Checkpoints
    if i%1000 == 0:
        print('%d iterations done in: ' % (k))
        print(timedelta(seconds=timer()-start))
        print('----------')
        
#Matrix as dataframe
print('-------------------- \n%Saving to .csv%')
df = pd.DataFrame(I, index=labels, columns=labels)
df.to_csv(r'Data/Inheritance.csv')

#End timer after loop    
end = timer()
print(timedelta(seconds=end-start))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [13], in <cell line: 5>()
#       2 start = timer()
#       4 #Empty matrix
# ----> 5 I = np.zeros((N, N))
#       6 for i in range(N):
#       7     for j in range(N):
#
# MemoryError: Unable to allocate 550. GiB for an array with shape (271727, 271727) and data type float64
